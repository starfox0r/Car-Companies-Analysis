# %% [markdown]
# ### This is a template car companie analysis

# %% [markdown]
# In this Template we take a look on 3 Big Car companies: Tesla, Ford & GM.

# %% [markdown]
# We go mainly with Tesla but its easy to replicate it for the other brands.

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import yfinance as yf
from pandas.plotting import scatter_matrix

# %% [markdown]
# Define a start and end date

# %%
startdate = datetime.datetime(2012,1,1)
enddate = datetime.datetime(2021,1,1)

# %% [markdown]
# Downloading Tickerdata and transform it into a .csv file

# %%
tsla = yf.download('TSLA',start=startdate,end=enddate)
f = yf.download('F',start=startdate,end=enddate)
gm = yf.download('GM',start=startdate,end=enddate)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tsla.to_csv('TSLA.csv')
f.to_csv('F.csv')
gm.to_csv('GM.csv')

# %% [markdown]
# ### Read the .csv file with pandas

# %%
tesla = pd.read_csv('TSLA.csv')
ford = pd.read_csv('F.csv')
gm = pd.read_csv('GM.csv')

# %%
tesla.info()
ford.info()
gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   object
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   object
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   object
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB

# %% [markdown]
# As can see there are no NaN or NULL entries so we can proceed

# %% [markdown]
# ### Take the first look on the data we downloaded into the .csv file

# %%
tesla.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2012-01-03  5.788  5.900  5.530  5.616      5.616  4640500
# 1  2012-01-04  5.642  5.734  5.500  5.542      5.542  3150500
# 2  2012-01-05  5.552  5.586  5.370  5.424      5.424  5027500
# 3  2012-01-06  5.440  5.558  5.282  5.382      5.382  4931500
# 4  2012-01-09  5.400  5.498  5.224  5.450      5.450  4485000

# %%
ford.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2012-01-03  11.00  11.25  10.99  11.13   7.544739  45709900
# 1  2012-01-04  11.15  11.53  11.07  11.30   7.659979  79725200
# 2  2012-01-05  11.33  11.63  11.24  11.59   7.856564  67877500
# 3  2012-01-06  11.74  11.80  11.52  11.71   7.937905  59840700
# 4  2012-01-09  11.83  11.95  11.70  11.80   7.998915  53981500

# %%
gm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2012-01-03  20.830000  21.180000  20.750000  21.049999  16.269411   9321300
# 1  2012-01-04  21.049999  21.370001  20.750000  21.150000  16.346706   7856700
# 2  2012-01-05  21.100000  22.290001  20.959999  22.170000  17.135056  17880600
# 3  2012-01-06  22.260000  23.030001  22.240000  22.920000  17.714725  18234500
# 4  2012-01-09  23.200001  23.430000  22.700001  22.840000  17.652891  12084500

# %%
tesla['Date'].min(), tesla['Date'].max()
# Out:
# ('2012-01-03', '2020-12-31')

# %%
tesla = tesla.set_index('Date')
ford = ford.set_index('Date')
gm = gm.set_index('Date')

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2265 entries, 2012-01-03 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2265 non-null   float64
#  1   High       2265 non-null   float64
#  2   Low        2265 non-null   float64
#  3   Close      2265 non-null   float64
#  4   Adj Close  2265 non-null   float64
#  5   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 123.9+ KB

# %% [markdown]
# ### All 3 stocks in comparison from 2010 to 2021

# %%
tesla['Open'].plot(figsize=(20,8), label='Tesla')
ford['Open'].plot(c='red', label='Ford')
gm['Open'].plot(c='green', label='GM')
plt.xlabel('Date')
plt.ylabel('Price in ($)')
plt.legend()
plt.grid()
plt.show()

# %%
tesla['Volume'].plot(c='blue',figsize=(20,8), label='Tesla')
ford['Volume'].plot(c='red', label='Ford')
gm['Volume'].plot(c='green', label='GM')
plt.grid()
plt.legend()
plt.show()

# %%
tesla.iloc[[tesla['Volume'].argmax()]]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02-04  176.591995  193.798004  166.776001  177.412003  177.412003
#
#                Volume
# Date
# 2020-02-04  304694000

# %%
tesla['Volume'].argmax()
# Out:
# 2034

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2020-03-31  5.03  5.19  4.75   4.83       4.83  231800800

# %%
ford['Volume'].argmax()
# Out:
# 2073

# %%
gm.iloc[[gm['Volume'].argmax()]]
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2014-01-15  39.630001  39.77  38.959999  39.380001  30.436543  89207600

# %%
gm['Volume'].argmax()
# Out:
# 511

# %% [markdown]
# This is the Volume spike which our earlier argmax() function told us to look at.

# %% [markdown]
# We can navigate with the iloc function (Example: 1:252 is 1 Year as a Year has 252 TradingDays.

# %%
tesla.iloc[750:]['Volume'].plot(figsize=(20,8))
plt.grid()
plt.show()

# %% [markdown]
# ### Adding a MarketCap column

# %%
tesla['MarketCap'] = tesla['Open'] * tesla['Volume']
ford['MarketCap'] = ford['Open'] * ford['Volume']
gm['MarketCap'] = gm['Open'] * gm['Volume']

# %%
tesla.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume     MarketCap
# Date
# 2012-01-03  5.788  5.900  5.530  5.616      5.616  4640500  2.685921e+07
# 2012-01-04  5.642  5.734  5.500  5.542      5.542  3150500  1.777512e+07
# 2012-01-05  5.552  5.586  5.370  5.424      5.424  5027500  2.791268e+07
# 2012-01-06  5.440  5.558  5.282  5.382      5.382  4931500  2.682736e+07
# 2012-01-09  5.400  5.498  5.224  5.450      5.450  4485000  2.421900e+07

# %%
tesla.iloc[1:252]['MarketCap'].plot(figsize=(20,8))
plt.grid()

# %% [markdown]
# ### Plotting the Moving Average

# %%
tesla.iloc[1:]['Open'].plot(figsize=(20,8), label='No Moving Average')
tesla['MA50'] = tesla['Open'].rolling(50).mean()
tesla.iloc[1:]['MA50'].plot(label='Moving Average 50', c='red')
tesla['MA200'] = tesla['Open'].rolling(200).mean()
tesla.iloc[1:]['MA200'].plot(label='Moving Average 200', c='green')
plt.legend()

# %% [markdown]
# ### Showing possible correlation

# %%
companies = pd.concat([tesla['Open'], ford['Open'], gm['Open']], axis=1)
companies.columns = ['Tesla Open', 'Ford Open', 'GM Open']

# %%
companies.head()
# Out:
#             Tesla Open  Ford Open    GM Open
# Date
# 2012-01-03       5.788      11.00  20.830000
# 2012-01-04       5.642      11.15  21.049999
# 2012-01-05       5.552      11.33  21.100000
# 2012-01-06       5.440      11.74  22.260000
# 2012-01-09       5.400      11.83  23.200001

# %%
scatter_matrix(companies, figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>]], dtype=object)

# %% [markdown]
# ### Adding Returns column

# %%
tesla['Returns'] = (tesla['Close']/tesla['Close'].shift(1)) - 1
ford['Returns'] = (ford['Close']/ford['Close'].shift(1)) - 1
gm['Returns'] = (gm['Close']/gm['Close'].shift(1)) - 1

# %%
tesla.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume     MarketCap  \
# Date
# 2012-01-03  5.788  5.900  5.530  5.616      5.616  4640500  2.685921e+07
# 2012-01-04  5.642  5.734  5.500  5.542      5.542  3150500  1.777512e+07
# 2012-01-05  5.552  5.586  5.370  5.424      5.424  5027500  2.791268e+07
# 2012-01-06  5.440  5.558  5.282  5.382      5.382  4931500  2.682736e+07
# 2012-01-09  5.400  5.498  5.224  5.450      5.450  4485000  2.421900e+07
#
#             MA50  MA200   Returns
# Date
# 2012-01-03   NaN    NaN       NaN
# 2012-01-04   NaN    NaN -0.013177
# 2012-01-05   NaN    NaN -0.021292
# 2012-01-06   NaN    NaN -0.007743
# 2012-01-09   NaN    NaN  0.012635

# %%
tesla['Returns'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Showing Volatility

# %%
tesla['Returns'].hist(bins=100, alpha=0.5, label='Tesla', figsize=(12,12))
ford['Returns'].hist(bins=100, alpha=0.5, label='Ford')
gm['Returns'].hist(bins=100, alpha=0.5, label='GM')
plt.legend()

# %% [markdown]
# ### Adding Comulative Return

# %%
tesla['Comulative Return'] = (1 + tesla['Returns']).cumprod()
ford['Comulative Return'] = (1 + ford['Returns']).cumprod()
gm['Comulative Return'] = (1 + gm['Returns']).cumprod()

# %%
tesla.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume     MarketCap  \
# Date
# 2012-01-03  5.788  5.900  5.530  5.616      5.616  4640500  2.685921e+07
# 2012-01-04  5.642  5.734  5.500  5.542      5.542  3150500  1.777512e+07
# 2012-01-05  5.552  5.586  5.370  5.424      5.424  5027500  2.791268e+07
# 2012-01-06  5.440  5.558  5.282  5.382      5.382  4931500  2.682736e+07
# 2012-01-09  5.400  5.498  5.224  5.450      5.450  4485000  2.421900e+07
#
#             MA50  MA200   Returns  Comulative Return
# Date
# 2012-01-03   NaN    NaN       NaN                NaN
# 2012-01-04   NaN    NaN -0.013177           0.986823
# 2012-01-05   NaN    NaN -0.021292           0.965812
# 2012-01-06   NaN    NaN -0.007743           0.958333
# 2012-01-09   NaN    NaN  0.012635           0.970442

# %%
tesla['Comulative Return'].plot(figsize=(20,8), label='Tesla')
ford['Comulative Return'].plot(label='Ford')
gm['Comulative Return'].plot(label='GM')
plt.title('Comulative Returns vs. Time')
plt.legend()
